# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline

from math import sqrt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Analysis imports
from pandas.plotting import lag_plot
from pylab import rcParams
from statsmodels.tsa.seasonal import seasonal_decompose
from pandas import DataFrame
from pandas import concat

# Modelling imports
from statsmodels.tsa.ar_model import AR
from statsmodels.tsa.arima_model import ARMA
from statsmodels.tsa.arima_model import ARIMA
from fbprophet import Prophet
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, GRU, RNN
from keras.layers import Dropout

# %% [markdown]
# input data of ABBANK

# %%
df = pd.read_csv('/content/Data_BSCCL.csv')
df.head()
# Out:
#          date  last_traded_price   high    low  opening_price  closing_price  \
# 0  2012-12-30              133.2  134.7  132.3          134.0          132.9
# 1  2012-12-27              134.5  135.9  132.9          135.9          134.8
# 2  2012-12-26              135.5  136.2  132.2          133.4          135.0
# 3  2012-12-24              130.8  132.8  127.1          130.8          131.8
# 4  2012-12-23              128.0  131.0  127.5          129.3          127.8
#
#    trade  value_mn  volume  month  day_of_month  day_of_year  day_of_week  \
# 0    939   54.3319  407900     12            30          365            6
# 1   1384   72.1679  535900     12            27          362            3
# 2   1658   67.1546  498000     12            26          361            2
# 3   1343   53.9809  412400     12            24          359            0
# 4    917   32.8732  255700     12            23          358            6
#
#    difference
# 0         2.4
# 1         3.0
# 2         4.0
# 3         5.7
# 4         3.5

# %%
df.index  = df['date']
df
# Out:
#                   date  last_traded_price   high    low  opening_price  \
# date
# 2012-12-30  2012-12-30              133.2  134.7  132.3          134.0
# 2012-12-27  2012-12-27              134.5  135.9  132.9          135.9
# 2012-12-26  2012-12-26              135.5  136.2  132.2          133.4
# 2012-12-24  2012-12-24              130.8  132.8  127.1          130.8
# 2012-12-23  2012-12-23              128.0  131.0  127.5          129.3
# ...                ...                ...    ...    ...            ...
# 2019-01-07  2019-01-07              105.0  108.0  101.0          106.5
# 2019-01-06  2019-01-06              105.0  107.0  101.5          101.5
# 2019-01-03  2019-01-03              102.1  102.6   98.0           98.0
# 2019-01-02  2019-01-02               97.0   97.5   95.5           97.4
# 2019-01-01  2019-01-01               97.0   97.2   93.2           93.5
#
#             closing_price  trade  value_mn  volume  month  day_of_month  \
# date
# 2012-12-30          132.9    939   54.3319  407900     12            30
# 2012-12-27          134.8   1384   72.1679  535900     12            27
# 2012-12-26          135.0   1658   67.1546  498000     12            26
# 2012-12-24          131.8   1343   53.9809  412400     12            24
# 2012-12-23          127.8    917   32.8732  255700     12            23
# ...                   ...    ...       ...     ...    ...           ...
# 2019-01-07          104.9    816   37.3990  351360      1             7
# 2019-01-06          105.5    741   40.2370  385064      1             6
# 2019-01-03          101.8   1034   34.6100  344680      1             3
# 2019-01-02           97.0    431   16.9800  175759      1             2
# 2019-01-01           96.7    521   26.4600  277493      1             1
#
#             day_of_year  day_of_week  difference
# date
# 2012-12-30          365            6         2.4
# 2012-12-27          362            3         3.0
# 2012-12-26          361            2         4.0
# 2012-12-24          359            0         5.7
# 2012-12-23          358            6         3.5
# ...                 ...          ...         ...
# 2019-01-07            7            0         7.0
# 2019-01-06            6            6         5.5
# 2019-01-03            3            3         4.6
# 2019-01-02            2            2         2.0
# 2019-01-01            1            1         4.0
#
# [1814 rows x 14 columns]

# %% [markdown]
# Take closing_price for prediction

# %%
values = DataFrame(df['closing_price'].values)
dataframe = concat([values.shift(1),values.shift(5),values.shift(10),values.shift(30), values], axis=1)
dataframe.columns = ['t', 't+1', 't+5', 't+10', 't+30']
result = dataframe.corr()
print(result)
# Out:
#              t       t+1       t+5      t+10      t+30
# t     1.000000  0.962237  0.917369  0.687790  0.985151
# t+1   0.962237  1.000000  0.953799  0.740785  0.953754
# t+5   0.917369  0.953799  1.000000  0.801266  0.906988
# t+10  0.687790  0.740785  0.801266  1.000000  0.674670
# t+30  0.985151  0.953754  0.906988  0.674670  1.000000

# %% [markdown]
# Split train and test data

# %%
train_data, test_data = df[0:-60], df[-60:]
plt.figure(figsize=(10,10))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Open Prices')
plt.plot(df['closing_price'].tail(600), 'green', label='Train data')
plt.plot(test_data['closing_price'], 'blue', label='Test data')
plt.legend()
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %% [markdown]
# Show the closing_price column data

# %%
df['closing_price']
# Out:
# date
# 2012-12-30    132.9
# 2012-12-27    134.8
# 2012-12-26    135.0
# 2012-12-24    131.8
# 2012-12-23    127.8
#               ...
# 2019-01-07    104.9
# 2019-01-06    105.5
# 2019-01-03    101.8
# 2019-01-02     97.0
# 2019-01-01     96.7
# Name: closing_price, Length: 1814, dtype: float64

# %% [markdown]
# We take 60 days data to test our models

# %%
test_data.shape
# Out:
# (60, 14)

# %%
train_data.closing_price.tail(30)
# Out:
# date
# 2019-05-15    136.2
# 2019-05-14    137.6
# 2019-05-13    139.8
# 2019-05-12    140.3
# 2019-05-09    144.2
# 2019-05-08    147.0
# 2019-05-07    146.6
# 2019-05-06    148.5
# 2019-05-05    152.8
# 2019-05-02    154.2
# 2019-04-30    147.3
# 2019-04-29    151.2
# 2019-04-28    155.0
# 2019-04-25    158.1
# 2019-04-24    156.0
# 2019-04-23    161.9
# 2019-04-21    171.0
# 2019-04-18    167.6
# 2019-04-17    164.4
# 2019-04-16    163.5
# 2019-04-15    161.0
# 2019-04-11    160.8
# 2019-04-10    153.4
# 2019-04-09    156.8
# 2019-04-08    159.4
# 2019-04-07    162.9
# 2019-04-04    159.9
# 2019-04-03    159.1
# 2019-04-02    162.7
# 2019-04-01    162.2
# Name: closing_price, dtype: float64

# %%
mean_value = df['closing_price'].mean() # calculation of mean price

plt.figure(figsize=(16,8))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Open Prices')
plt.plot(df['closing_price'], 'green', label='Train data')
plt.plot(test_data['closing_price'], 'blue', label='Test data')
plt.axhline(y=mean_value, xmin=0.864, xmax=1, color='red')
plt.legend()

plt.figure(figsize=(16,8))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Open Prices')
plt.plot(df['closing_price'].tail(600), 'green', label='Train data')
plt.plot(test_data['closing_price'], 'blue', label='Test data')
plt.axhline(y=mean_value, xmin=0.864, xmax=1, color='red')
plt.legend()

print('MSE: '+str(mean_squared_error(test_data['closing_price'], np.full(len(test_data), mean_value))))
print('MAE: '+str(mean_absolute_error(test_data['closing_price'], np.full(len(test_data), mean_value))))
print('RMSE: '+str(sqrt(mean_squared_error(test_data['closing_price'], np.full(len(test_data), mean_value)))))
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# MSE: 638.3401923130825
# MAE: 22.28227306137447
# RMSE: 25.265395154500997

# %% [markdown]
# Train data for ARIMA model

# %%
train_arima = train_data['closing_price']
test_arima = test_data['closing_price']

history = [x for x in train_arima]
y = test_arima
# make first prediction
predictions = list()
model = ARIMA(history, order=(1,1,0))
model_fit = model.fit(disp=0)
yhat = model_fit.forecast()[0]
predictions.append(yhat)
history.append(y[0])
# rolling forecasts
for i in range(1, len(y)):
    # predict
    model = ARIMA(history, order=(1,1,1))
    model_fit = model.fit(disp=0)
    yhat = model_fit.forecast()[0]
    # invert transformed prediction
    predictions.append(yhat)
    # observation
    obs = y[i]
    history.append(obs)
    
plt.figure(figsize=(14,8))
plt.plot(df.index, df['closing_price'], color='green', label = 'Train Stock Price')
plt.plot(test_data.index, y, color = 'red', label = 'Real Stock Price')
plt.plot(test_data.index, predictions, color = 'blue', label = 'Predicted Stock Price')
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(14,8))
plt.plot(df.index[-600:], df['closing_price'].tail(600), color='green', label = 'Train Stock Price')
plt.plot(test_data.index, y, color = 'red', label = 'Real Stock Price')
plt.plot(test_data.index, predictions, color = 'blue', label = 'Predicted Stock Price')
plt.legend()
plt.grid(True)
plt.show()

print('MSE: '+str(mean_squared_error(y, predictions)))
print('MAE: '+str(mean_absolute_error(y, predictions)))
print('RMSE: '+str(sqrt(mean_squared_error(y, predictions))))
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# MSE: 27.375115553292307
# MAE: 4.047493129571762
# RMSE: 5.2321234268021914

# %%
test_data.reset_index(drop=True, inplace=True)

# %% [markdown]
# Predicted result for ARIMA model

# %%
#y_test = df.iloc[int(7200): ,0:1].values
plt.figure(figsize=(6,3.5))
#plt.suptitle('Sine and cosine waves', fontsize=13)
plt.plot(predictions, color='blue', label='Predicted closing price')
plt.plot(test_data['closing_price'], color ='red', label='Actual closing price')
plt.xlabel('Amount of days', fontsize=10)
plt.ylabel('Amount of price (Taka)', fontsize=10)
#plt.xticks(rotation=0,fontsize=12)
#plt.yticks(rotation=0,fontsize=12)
plt.grid(True)
#plt.savefig('ARIMA_Close_Price.jpeg')
plt.legend()
plt.show()

# %% [markdown]
# Pre-process data for Prophet model

# %%
ph_df_train = train_data.drop(['last_traded_price', 'high', 'low','opening_price',
                               'trade','value_mn','volume','month','day_of_month',
                               'day_of_year','day_of_week','difference'], axis=1)
ph_df_train['date'] = ph_df_train.index
ph_df_train.rename(columns={'closing_price': 'y', 'date': 'ds'}, inplace=True)

prop = Prophet(changepoint_prior_scale=0.1)
prop.fit(ph_df_train)
# Create Future dates
future_prices = prop.make_future_dataframe(periods=73)

# Predict Prices
forecast = prop.predict(future_prices)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast['yhat']
# Out:
# 0        41.061822
# 1        45.867024
# 2        47.592033
# 3        50.116780
# 4        51.318904
#            ...
# 1821    135.260702
# 1822    134.660349
# 1823    134.884523
# 1824    133.829295
# 1825    134.006361
# Name: yhat, Length: 1826, dtype: float64

# %%
plt.figure(figsize=(14,8))
plt.plot(df.index, df['closing_price'], color='green', label = 'Train Stock Price')
plt.plot(test_data.index, test_data['closing_price'], color = 'red', label = 'Real Stock Price')
plt.plot(test_data.index, forecast['yhat'][-60:], color = 'blue', label = 'Predicted Stock Price')
plt.fill_between(test_data.index, forecast['yhat_lower'][-60:], forecast['yhat_upper'][-60:], color='grey', label="Band Range")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(14,8))
plt.plot(df.index[-600:], df['closing_price'].tail(600), color='green', label = 'Train Stock Price')
plt.plot(test_data.index, test_data['closing_price'], color = 'red', label = 'Real Stock Price')
plt.plot(test_data.index, forecast['yhat'][-60:], color = 'blue', label = 'Predicted Stock Price')
plt.fill_between(test_data.index, forecast['yhat_lower'][-60:], forecast['yhat_upper'][-60:], color='grey', label="Band Range")
plt.legend()
plt.grid(True)
plt.show()
print('MSE: '+str(mean_squared_error(test_data['closing_price'], forecast['yhat'][-60:])))
print('MAE: '+str(mean_absolute_error(test_data['closing_price'], forecast['yhat'][-60:])))
print('RMSE: '+str(sqrt(mean_squared_error(test_data['closing_price'], forecast['yhat'][-60:]))))
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# MSE: 1055.2160332571864
# MAE: 29.349288812248894
# RMSE: 32.484088924536366

# %%
train = train_data.iloc[:, 1:2].values # selecting open prices
# Feature Scaling
scaler = MinMaxScaler()
train_scaled = scaler.fit_transform(train) 
# Train dataset
timesteps = 7
X_train = []
y_train = []
for i in range(timesteps, train.shape[0]):
    X_train.append(train_scaled[i-timesteps:i, 0]) # we take 30 previous prices
    y_train.append(train_scaled[i, 0]) # and 60-th price as y value
X_train, y_train = np.array(X_train), np.array(y_train)
# Reshaping
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
from numpy.random import seed
seed(2019)

# %% [markdown]
# LSTM model training

# %%
model = Sequential()

# Adding the first LSTM layer 
# Here return_sequences=True means whether to return the last output in the output sequence, or the full sequence.
# it basically tells us that there is another(or more) LSTM layer ahead in the network.
model.add(LSTM(units = 60, return_sequences = True, input_shape = (X_train.shape[1], 1)))
# Dropout regularisation for tackling overfitting
#model.add(Dropout(0.2))

model.add(LSTM(units = 50))
#model.add(Dropout(0.25))

# Adding the output layer
model.add(Dense(units = 1))

# Compiling the RNN
# RMSprop is a recommended optimizer as per keras documentation
# check out https://keras.io/optimizers/ for more details
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
model.fit(X_train, y_train, epochs = 100, batch_size = 16)
# Out:
# Epoch 1/100
# 110/110 [==============================] - 5s 9ms/step - loss: 0.0098
# Epoch 2/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0020
# Epoch 3/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0019
# Epoch 4/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0019
# Epoch 5/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0018
# Epoch 6/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0018
# Epoch 7/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0019
# Epoch 8/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0019
# Epoch 9/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0017
# Epoch 10/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0018
# Epoch 11/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0018
# Epoch 12/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0016
# Epoch 13/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0017
# Epoch 14/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0017
# Epoch 15/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0018
# Epoch 16/100
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0017
# Epoch 17/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0016
# Epoch 18/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0015
# Epoch 19/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0016
# Epoch 20/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0016
# Epoch 21/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0016
# Epoch 22/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0016
# Epoch 23/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0016
# Epoch 24/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0015
# Epoch 25/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0015
# Epoch 26/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0015
# Epoch 27/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0015
# Epoch 28/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0015
# Epoch 29/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0015
# Epoch 30/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0015
# Epoch 31/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0015
# Epoch 32/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0015
# Epoch 33/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0014
# Epoch 34/100
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 35/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0014
# Epoch 36/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0015
# Epoch 37/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0015
# Epoch 38/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0014
# Epoch 39/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0014
# Epoch 40/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0015
# Epoch 41/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0015
# Epoch 42/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0014
# Epoch 43/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0014
# Epoch 44/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0014
# Epoch 45/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0015
# Epoch 46/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0014
# Epoch 48/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0015
# Epoch 49/100
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 50/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0014
# Epoch 51/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0015
# Epoch 52/100
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 53/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0014
# Epoch 54/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0014
# Epoch 55/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0014
# Epoch 56/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0014
# Epoch 57/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0014
# Epoch 58/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0014
# Epoch 59/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0013
# Epoch 60/100
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 61/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0013
# Epoch 62/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0014
# Epoch 63/100
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 64/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0013
# Epoch 65/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0013
# Epoch 66/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0013
# Epoch 67/100
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 68/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0014
# Epoch 69/100
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 70/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0013
# Epoch 71/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0013
# Epoch 72/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0013
# Epoch 73/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0013
# Epoch 74/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0012
# Epoch 75/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0012
# Epoch 76/100
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0012
# Epoch 77/100
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 78/100
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0012
# Epoch 79/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0012
# Epoch 80/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0012
# Epoch 81/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0012
# Epoch 82/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0012
# Epoch 83/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0012
# Epoch 84/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0012
# Epoch 85/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0012
# Epoch 86/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0012
# Epoch 87/100
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0012
# Epoch 88/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0012
# Epoch 89/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0012
# Epoch 90/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0012
# Epoch 91/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0011
# Epoch 92/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0011
# Epoch 93/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0011
# Epoch 94/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0011
# Epoch 95/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0012
# Epoch 96/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0011
# Epoch 97/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0012
# Epoch 98/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0011
# Epoch 99/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0011
# Epoch 100/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0012

# %%
# this will be used later while comparing and visualization
real_stock_price = test_data.iloc[:,1:2].values # taking open price
# combine original train and test data vertically
# as previous Open Prices are not present in test dataset
# e.g. for predicting Open price for first date in test data, we will need stock open prices on timesteps previous dates  
combine = pd.concat((train_data['closing_price'], test_data['closing_price']), axis = 0)
# our test inputs also contains stock open Prices of last timesteps dates (as described above)
test_inputs = combine[len(combine) - len(test_data) - timesteps:].values
test_inputs = test_inputs.reshape(-1,1)
test_inputs = scaler.transform(test_inputs)
# same steps as we followed while processing training data
X_test = []
for i in range(timesteps, test_data.shape[0]+timesteps):
    X_test.append(test_inputs[i-timesteps:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = model.predict(X_test)
# inverse_transform because prediction is done on scaled inputs
predicted_stock_price = scaler.inverse_transform(predicted_stock_price)
# Out:
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f9287fe7ef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f9287fe7ef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# Predicted result for LSTM model

# %%
plt.figure(figsize=(16,8))
plt.plot(df.index[-600:], df['closing_price'].tail(600), color='green', label = 'Train Stock Price')
plt.plot(test_data.index, real_stock_price, color = 'red', label = 'Real Stock Price')
plt.plot(test_data.index, predicted_stock_price, color = 'blue', label = 'Predicted Stock Price')
plt.title('Dhaka Stock Exchange Closing price Prediction')
plt.xlabel('Time')
plt.ylabel('Dhaka Stock Exchange Closing price')
plt.legend()
plt.grid(True)
#plt.savefig('lstm_30.pdf')
plt.show()

mse = mean_squared_error(real_stock_price, predicted_stock_price)
print('MSE: '+str(mse))
mae = mean_absolute_error(real_stock_price, predicted_stock_price)
print('MAE: '+str(mae))
rmse = sqrt(mean_squared_error(real_stock_price, predicted_stock_price))
print('RMSE: '+str(rmse))
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# MSE: 27.26269023640858
# MAE: 4.068797251383464
# RMSE: 5.221368617173909

# %%
test_data.reset_index(drop=True, inplace=True)
#y_test = df.iloc[int(7200): ,0:1].values
plt.figure(figsize=(6,3.5))
#plt.suptitle('Sine and cosine waves', fontsize=13)
plt.plot(predicted_stock_price, color='blue', label='Predicted Opening Price')
plt.plot(test_data['closing_price'], color ='red', label='Actual Opening Price')
plt.xlabel('Amount of days', fontsize=10)
plt.ylabel('Amount of price (Taka)', fontsize=10)
#plt.xticks(rotation=0,fontsize=12)
#plt.yticks(rotation=0,fontsize=12)
plt.grid(True)
#plt.savefig('LSTM_opening_price.jpeg')
plt.legend()
plt.show()

# %% [markdown]
# Training data by GRU model

# %%
model = Sequential()

# Adding the first GRU layer 
# Here return_sequences=True means whether to return the last output in the output sequence, or the full sequence.
# it basically tells us that there is another(or more) GRU layer ahead in the network.
model.add(GRU(units = 60, return_sequences = True, input_shape = (X_train.shape[1], 1)))
# Dropout regularisation for tackling overfitting
model.add(Dropout(0.2))

model.add(GRU(units = 50))
model.add(Dropout(0.25))

# Adding the output layer
model.add(Dense(units = 1))

# Compiling the RNN
# RMSprop is a recommended optimizer as per keras documentation
# check out https://keras.io/optimizers/ for more details
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
model.fit(X_train, y_train, epochs = 200, batch_size = 16)
# Out:
# Epoch 1/200
# 110/110 [==============================] - 5s 8ms/step - loss: 0.0085
# Epoch 2/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0035
# Epoch 3/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0030
# Epoch 4/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0030
# Epoch 5/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0029
# Epoch 6/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0028
# Epoch 7/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0028
# Epoch 8/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0028
# Epoch 9/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0024
# Epoch 10/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0024
# Epoch 11/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0022
# Epoch 12/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0027
# Epoch 13/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0025
# Epoch 14/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0021
# Epoch 15/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0023
# Epoch 16/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0023
# Epoch 17/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0021
# Epoch 18/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0019
# Epoch 19/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0020
# Epoch 20/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0021
# Epoch 21/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0020
# Epoch 22/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0019
# Epoch 23/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0018
# Epoch 24/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0017
# Epoch 25/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0019
# Epoch 26/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0017
# Epoch 27/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0018
# Epoch 28/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0018
# Epoch 29/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0019
# Epoch 30/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0017
# Epoch 31/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0017
# Epoch 32/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0018
# Epoch 33/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0018
# Epoch 34/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0015
# Epoch 35/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0016
# Epoch 36/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0016
# Epoch 37/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0016
# Epoch 38/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0015
# Epoch 39/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0015
# Epoch 40/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0015
# Epoch 41/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0015
# Epoch 42/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0015
# Epoch 43/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 44/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 45/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 46/200
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0015
# Epoch 47/200
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0014
# Epoch 48/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0016
# Epoch 49/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0015
# Epoch 50/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 51/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0015
# Epoch 52/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 53/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0015
# Epoch 54/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0015
# Epoch 55/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0015
# Epoch 56/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 57/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0015
# Epoch 58/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 59/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0015
# Epoch 60/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 61/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0015
# Epoch 62/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 63/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 64/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 65/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 66/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 67/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 68/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0015
# Epoch 69/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 70/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 71/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 72/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0015
# Epoch 73/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 74/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 75/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 76/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 77/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 78/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 79/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 80/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 81/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0015
# Epoch 82/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 83/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 84/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 85/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 86/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 87/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 88/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 89/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 90/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 91/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 92/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0012
# Epoch 93/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 94/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 95/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 96/200
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0013
# Epoch 97/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 98/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 99/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 100/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0012
# Epoch 101/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 102/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 103/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 104/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 105/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 106/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 107/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 108/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 109/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 110/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 111/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 112/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 113/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 114/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 115/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 116/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 117/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 118/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 119/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 120/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 121/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 122/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 123/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 124/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 125/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 126/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 127/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 128/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 129/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0012
# Epoch 130/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 131/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 132/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 133/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 134/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 135/200
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0013
# Epoch 136/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 137/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 138/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 139/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 140/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 141/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 142/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 143/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 144/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 145/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 146/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 147/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 148/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0012
# Epoch 149/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 150/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 151/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 152/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 153/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 154/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 155/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 156/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 157/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 158/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 159/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 160/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 161/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 162/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 163/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 164/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 165/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 166/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 167/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 168/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 169/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 170/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 171/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 172/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 173/200
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0013
# Epoch 174/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 175/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 176/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 177/200
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0013
# Epoch 178/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 179/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0012
# Epoch 180/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 181/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 182/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 183/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 184/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 185/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0014
# Epoch 186/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 187/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0012
# Epoch 188/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 189/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 190/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 191/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 192/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0012
# Epoch 193/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 194/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0012
# Epoch 195/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 196/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0012
# Epoch 197/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0012
# Epoch 198/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013
# Epoch 199/200
# 110/110 [==============================] - 1s 9ms/step - loss: 0.0013
# Epoch 200/200
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0013

# %%
# this will be used later while comparing and visualization
real_stock_price_GRU = test_data.iloc[:,1:2].values # taking open price
# combine original train and test data vertically
# as previous Open Prices are not present in test dataset
# e.g. for predicting Open price for first date in test data, we will need stock open prices on timesteps previous dates  
combine = pd.concat((train_data['closing_price'], test_data['closing_price']), axis = 0)
# our test inputs also contains stock open Prices of last timesteps dates (as described above)
test_inputs = combine[len(combine) - len(test_data) - timesteps:].values
test_inputs = test_inputs.reshape(-1,1)
test_inputs = scaler.transform(test_inputs)
# same steps as we followed while processing training data
X_test = []
for i in range(timesteps, test_data.shape[0]+timesteps):
    X_test.append(test_inputs[i-timesteps:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price_GRU = model.predict(X_test)
# inverse_transform because prediction is done on scaled inputs
predicted_stock_price_GRU = scaler.inverse_transform(predicted_stock_price_GRU)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f9287fe7a70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f9287fe7a70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
plt.figure(figsize=(16,8))
plt.plot(df.index[-600:], df['closing_price'].tail(600), color='green', label = 'Train Stock Price')
plt.plot(test_data.index, real_stock_price_GRU, color = 'red', label = 'Real Stock Price')
plt.plot(test_data.index, predicted_stock_price_GRU, color = 'blue', label = 'Predicted Stock Price')
plt.title('Dhaka Stock Exchange Closing price Prediction')
plt.xlabel('Time')
plt.ylabel('Dhaka Stock Exchange Closing price')
plt.legend()
plt.grid(True)
plt.savefig('lstm_30.pdf')
plt.show()

mse = mean_squared_error(real_stock_price_GRU, predicted_stock_price_GRU)
print('MSE: '+str(mse))
mae = mean_absolute_error(real_stock_price_GRU, predicted_stock_price_GRU)
print('MAE: '+str(mae))
rmse = sqrt(mean_squared_error(real_stock_price_GRU, predicted_stock_price_GRU))
print('RMSE: '+str(rmse))
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# MSE: 26.937685320465448
# MAE: 4.048414510091146
# RMSE: 5.190152726121404

# %%
plt.figure(figsize=(16,8))
#print('Lag: %s' % model_fit.k_ar)
plt.plot(df.index[-100:], df['closing_price'].tail(100), color='green', label='Close price')
plt.plot(test_data.index, test_data['closing_price'], color='red', label='Test close price')
plt.plot(test_data.index, predicted_stock_price_GRU, color='blue', label='Predicted close price')
plt.xlabel('Date', fontsize=10)
plt.xticks(rotation=90,fontsize=7)
#plt.grid(True)
plt.legend()
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
